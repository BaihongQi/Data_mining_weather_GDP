# %%
import pandas as pd

# %%
X = pd.read_csv('data/data.csv')

# %%
lis=['MCIC_hr','Vis_hr','Ceiling_hr','TS_hr','CW0422_hr','CW1129_hr','PC_hr','RNSNIC_hr','CW0422_Str','CW1129_Str']
lis2=['ModNumber','ActAdvisoryDuration','PR_hr','GDPCNX']
df=X[lis+lis2]

# %%
df
# Out:
#       MCIC_hr  Vis_hr  Ceiling_hr  TS_hr  CW0422_hr  CW1129_hr  PC_hr  \
# 0           1     5.0          25      0         29         15      1
# 1           0     6.0          40      0         30         15      1
# 2           0     6.0          40      0         30         15      1
# 3           0     6.0          40      0         30         15      1
# 4           0    10.0          50      0         32         16      1
# 5           0    10.0          50      0         32         16      1
# 6           0    10.0          50      0         32         16      1
# 7           0    10.0          50      0         32         16      1
# 8           0    10.0          70      0         36         19      0
# 9           0    10.0          70      0         36         19      0
# 10          0    10.0          70      0         36         19      0
# 11          0    10.0         250      0         34          6      0
# ...

# %%
df.to_csv('forecast_influence.csv')
