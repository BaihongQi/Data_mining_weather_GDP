# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(1000)

# %%
data
# Out:
# (array([[ -2.29998048,  -1.80183098],
#         [-10.72227484,   0.57414019],
#         [ -7.37825827,   1.18559926],
#         ...,
#         [ -2.46798511,  -0.82578891],
#         [ -9.38936816,  -0.79260184],
#         [ -1.23719736,  -2.05485915]]),
#  array([2, 0, 0, 2, 2, 1, 2, 0, 2, 0, 0, 1, 1, 2, 0, 2, 1, 1, 2, 0, 1, 2, 2,
#         1, 1, 1, 0, 2, 0, 2, 2, 0, 1, 2, 2, 1, 0, 0, 1, 2, 2, 1, 0, 1, 2, 0,
#         0, 0, 0, 1, 0, 1, 1, 2, 2, 0, 0, 2, 0, 0, 1, 2, 0, 2, 2, 2, 1, 2, 1,
#         0, 1, 1, 2, 1, 1, 2, 1, 0, 0, 1, 1, 2, 0, 2, 2, 2, 0, 1, 1, 1, 2, 1,
#         1, 0, 2, 0, 2, 0, 1, 2, 2, 0, 2, 0, 1, 1, 2, 1, 1, 0, 0, 2, 2, 2, 2,
#         1, 0, 0, 0, 1, 1, 1, 0, 0, 1, 0, 1, 1, 1, 2, 1, 1, 0, 2, 1, 2, 0, 0,
#         2, 0, 1, 0, 1, 0, 2, 0, 1, 2, 2, 2, 1, 0, 0, 0, 2, 0, 2, 0, 0, 0, 2,
#         1, 0, 1, 2, 0, 1, 0, 0, 2, 0, 1, 1, 2, 1, 2, 0, 0, 2, 1, 0, 2, 2, 1,
#         2, 0, 2, 0, 2, 2, 1, 1, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 0, 0, 1, 1,
# ...
